# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, 2000)
lngs = np.random.uniform(-180.000, 180.000, 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdescrip = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_wdescrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | san jose de rio tinto
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | ambilobe
# Processing Record 5 of Set 1 | dezhou
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | ingham
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | warrington
# Processing Record 11 of Set 1 | aripuana
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | manaia
# Processing Record 14 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 1 | rocha
# Processing Record 16 of Set 1 | hami
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | ibarra
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | moorhead
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | nago
# Processing Record 23 of Set 1 | cartagena
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | tambopata
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | lagoa
# Processing Record 28 of Set 1 | pangnirtung
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | stokmarknes
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | saint-leu
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | rolla
# Processing Record 36 of Set 1 | sorland
# Processing Record 37 of Set 1 | necocli
# Processing Record 38 of Set 1 | puqi
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | karaton
# Processing Record 44 of Set 1 | oistins
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | walvis bay
# Processing Record 49 of Set 1 | senneterre
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | broken hill
# Processing Record 3 of Set 2 | amalapuram
# Processing Record 4 of Set 2 | khani
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | tiznit
# Processing Record 7 of Set 2 | ukhta
# Processing Record 8 of Set 2 | college
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | caravelas
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | mecca
# Processing Record 14 of Set 2 | eregli
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | kavieng
# Processing Record 17 of Set 2 | leningradskiy
# Processing Record 18 of Set 2 | taltal
# Processing Record 19 of Set 2 | yulara
# Processing Record 20 of Set 2 | pisco
# Processing Record 21 of Set 2 | dubenskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | manzhouli
# Processing Record 26 of Set 2 | ahuimanu
# Processing Record 27 of Set 2 | kipushi
# Processing Record 28 of Set 2 | berbera
# Processing Record 29 of Set 2 | port hardy
# Processing Record 30 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 2 | margate
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 34 of Set 2 | kajaani
# Processing Record 35 of Set 2 | dehloran
# Processing Record 36 of Set 2 | umba
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | athabasca
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | nivala
# Processing Record 43 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | elliot
# Processing Record 45 of Set 2 | northam
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | touros
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | flin flon
# Processing Record 4 of Set 3 | cabo san lucas
# Processing Record 5 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 3 | roald
# Processing Record 7 of Set 3 | lavrentiya
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | leshukonskoye
# Processing Record 10 of Set 3 | lincoln
# Processing Record 11 of Set 3 | guhagar
# Processing Record 12 of Set 3 | magistralnyy
# Processing Record 13 of Set 3 | kankavli
# City not found. Skipping...
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | tezu
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | saint-joseph
# Processing Record 18 of Set 3 | yei
# Processing Record 19 of Set 3 | gimli
# Processing Record 20 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 3 | shingu
# Processing Record 22 of Set 3 | kapoeta
# Processing Record 23 of Set 3 | san quintin
# Processing Record 24 of Set 3 | sitka
# Processing Record 25 of Set 3 | olafsvik
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | missoula
# Processing Record 29 of Set 3 | manacapuru
# Processing Record 30 of Set 3 | isangel
# Processing Record 31 of Set 3 | acurenam
# Processing Record 32 of Set 3 | port shepstone
# Processing Record 33 of Set 3 | turukhansk
# Processing Record 34 of Set 3 | necochea
# Processing Record 35 of Set 3 | udachnyy
# Processing Record 36 of Set 3 | la uribe
# City not found. Skipping...
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | itapetininga
# Processing Record 39 of Set 3 | guaruja
# Processing Record 40 of Set 3 | fort nelson
# Processing Record 41 of Set 3 | la libertad
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | fortuna
# Processing Record 44 of Set 3 | hasaki
# Processing Record 45 of Set 3 | caxito
# Processing Record 46 of Set 3 | kuytun
# Processing Record 47 of Set 3 | murray bridge
# Processing Record 48 of Set 3 | ziro
# Processing Record 49 of Set 3 | sur
# Processing Record 50 of Set 3 | dondo
# Processing Record 1 of Set 4 | sola
# Processing Record 2 of Set 4 | port alfred
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | reyes
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | camocim
# Processing Record 7 of Set 4 | luderitz
# Processing Record 8 of Set 4 | praia
# Processing Record 9 of Set 4 | tottori
# Processing Record 10 of Set 4 | encheng
# Processing Record 11 of Set 4 | paamiut
# Processing Record 12 of Set 4 | porto walter
# Processing Record 13 of Set 4 | alekseyevka
# Processing Record 14 of Set 4 | pathein
# Processing Record 15 of Set 4 | pokhara
# Processing Record 16 of Set 4 | robertsport
# Processing Record 17 of Set 4 | priiskovyy
# Processing Record 18 of Set 4 | yeppoon
# Processing Record 19 of Set 4 | zhaotong
# Processing Record 20 of Set 4 | vao
# Processing Record 21 of Set 4 | itarema
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | sovetskiy
# Processing Record 24 of Set 4 | north myrtle beach
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 4 | malanje
# Processing Record 28 of Set 4 | fethiye
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | bandarbeyla
# Processing Record 31 of Set 4 | corum
# Processing Record 32 of Set 4 | maues
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | hasanabad
# Processing Record 35 of Set 4 | hualmay
# Processing Record 36 of Set 4 | kinna
# Processing Record 37 of Set 4 | panji
# Processing Record 38 of Set 4 | atambua
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | mackay
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | ust-kuyga
# Processing Record 43 of Set 4 | victoria
# Processing Record 44 of Set 4 | ca mau
# Processing Record 45 of Set 4 | huambo
# Processing Record 46 of Set 4 | harnosand
# Processing Record 47 of Set 4 | arys
# Processing Record 48 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 4 | noyabrsk
# Processing Record 50 of Set 4 | puerto del rosario
# Processing Record 1 of Set 5 | camacha
# Processing Record 2 of Set 5 | wiang sa
# Processing Record 3 of Set 5 | mount gambier
# Processing Record 4 of Set 5 | kysyl-syr
# Processing Record 5 of Set 5 | sokode
# Processing Record 6 of Set 5 | klaksvik
# Processing Record 7 of Set 5 | aleksandrov gay
# Processing Record 8 of Set 5 | monastyrshchina
# Processing Record 9 of Set 5 | iqaluit
# Processing Record 10 of Set 5 | mopti
# Processing Record 11 of Set 5 | bubaque
# Processing Record 12 of Set 5 | carthage
# Processing Record 13 of Set 5 | east london
# Processing Record 14 of Set 5 | arlit
# Processing Record 15 of Set 5 | pankrushikha
# Processing Record 16 of Set 5 | roma
# Processing Record 17 of Set 5 | biltine
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | vuktyl
# Processing Record 21 of Set 5 | talnakh
# Processing Record 22 of Set 5 | bengkulu
# Processing Record 23 of Set 5 | norman wells
# Processing Record 24 of Set 5 | rovinj
# Processing Record 25 of Set 5 | alofi
# Processing Record 26 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | port lincoln
# Processing Record 29 of Set 5 | mehamn
# Processing Record 30 of Set 5 | san cristobal
# Processing Record 31 of Set 5 | el campo
# Processing Record 32 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 5 | dongsheng
# Processing Record 34 of Set 5 | daru
# Processing Record 35 of Set 5 | nome
# Processing Record 36 of Set 5 | olga
# Processing Record 37 of Set 5 | matara
# Processing Record 38 of Set 5 | cayenne
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 5 | gat
# Processing Record 42 of Set 5 | dikson
# Processing Record 43 of Set 5 | north bend
# Processing Record 44 of Set 5 | kristiinankaupunki
# Processing Record 45 of Set 5 | poronaysk
# Processing Record 46 of Set 5 | bairiki
# Processing Record 47 of Set 5 | chongwe
# Processing Record 48 of Set 5 | kodinsk
# Processing Record 49 of Set 5 | kosikha
# Processing Record 50 of Set 5 | helong
# Processing Record 1 of Set 6 | vilyuysk
# Processing Record 2 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 6 | wamba
# Processing Record 4 of Set 6 | phalodi
# Processing Record 5 of Set 6 | goderich
# Processing Record 6 of Set 6 | arraial do cabo
# Processing Record 7 of Set 6 | grindavik
# Processing Record 8 of Set 6 | ormara
# Processing Record 9 of Set 6 | naze
# Processing Record 10 of Set 6 | avarua
# Processing Record 11 of Set 6 | prince rupert
# Processing Record 12 of Set 6 | claveria
# Processing Record 13 of Set 6 | tromso
# Processing Record 14 of Set 6 | faya
# Processing Record 15 of Set 6 | pimenta bueno
# Processing Record 16 of Set 6 | acarau
# Processing Record 17 of Set 6 | martil
# Processing Record 18 of Set 6 | honiara
# Processing Record 19 of Set 6 | shimoda
# Processing Record 20 of Set 6 | visnes
# Processing Record 21 of Set 6 | iracoubo
# Processing Record 22 of Set 6 | piterka
# Processing Record 23 of Set 6 | hofn
# Processing Record 24 of Set 6 | henties bay
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | harper
# Processing Record 27 of Set 6 | bathsheba
# Processing Record 28 of Set 6 | sangar
# Processing Record 29 of Set 6 | shakiso
# Processing Record 30 of Set 6 | tuy hoa
# Processing Record 31 of Set 6 | cockburn town
# Processing Record 32 of Set 6 | port elizabeth
# Processing Record 33 of Set 6 | ribeira grande
# Processing Record 34 of Set 6 | coahuayana
# Processing Record 35 of Set 6 | tam ky
# Processing Record 36 of Set 6 | berlevag
# Processing Record 37 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 38 of Set 6 | loa janan
# Processing Record 39 of Set 6 | manitowoc
# Processing Record 40 of Set 6 | moratuwa
# Processing Record 41 of Set 6 | xai-xai
# Processing Record 42 of Set 6 | yamada
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | carnarvon
# Processing Record 45 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 46 of Set 6 | gushikawa
# Processing Record 47 of Set 6 | leh
# Processing Record 48 of Set 6 | airai
# Processing Record 49 of Set 6 | moerai
# Processing Record 50 of Set 6 | davila
# Processing Record 1 of Set 7 | monrovia
# Processing Record 2 of Set 7 | kaka
# Processing Record 3 of Set 7 | palana
# Processing Record 4 of Set 7 | balrampur
# Processing Record 5 of Set 7 | paralimni
# Processing Record 6 of Set 7 | burica
# City not found. Skipping...
# Processing Record 7 of Set 7 | inhambane
# Processing Record 8 of Set 7 | ballina
# Processing Record 9 of Set 7 | kutum
# Processing Record 10 of Set 7 | asau
# Processing Record 11 of Set 7 | imbituba
# Processing Record 12 of Set 7 | pacific grove
# Processing Record 13 of Set 7 | sumy
# Processing Record 14 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 7 | egvekinot
# Processing Record 16 of Set 7 | qasigiannguit
# Processing Record 17 of Set 7 | pacora
# Processing Record 18 of Set 7 | yenagoa
# Processing Record 19 of Set 7 | juneau
# Processing Record 20 of Set 7 | fairbanks
# Processing Record 21 of Set 7 | zhigansk
# Processing Record 22 of Set 7 | dingle
# Processing Record 23 of Set 7 | kapustin yar-1
# City not found. Skipping...
# Processing Record 24 of Set 7 | rypefjord
# Processing Record 25 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 7 | dryden
# Processing Record 28 of Set 7 | port hedland
# Processing Record 29 of Set 7 | ailigandi
# Processing Record 30 of Set 7 | muswellbrook
# Processing Record 31 of Set 7 | anloga
# Processing Record 32 of Set 7 | faanui
# Processing Record 33 of Set 7 | altay
# Processing Record 34 of Set 7 | hammerfest
# Processing Record 35 of Set 7 | les cayes
# Processing Record 36 of Set 7 | narsaq
# Processing Record 37 of Set 7 | camacupa
# Processing Record 38 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 7 | maceio
# Processing Record 40 of Set 7 | tessalit
# Processing Record 41 of Set 7 | doische
# Processing Record 42 of Set 7 | hirara
# Processing Record 43 of Set 7 | baracoa
# Processing Record 44 of Set 7 | soyo
# Processing Record 45 of Set 7 | flinders
# Processing Record 46 of Set 7 | riyadh
# Processing Record 47 of Set 7 | esperance
# Processing Record 48 of Set 7 | nanortalik
# Processing Record 49 of Set 7 | marsh harbour
# Processing Record 50 of Set 7 | bam
# Processing Record 1 of Set 8 | husavik
# Processing Record 2 of Set 8 | kirakira
# Processing Record 3 of Set 8 | nikolskoye
# Processing Record 4 of Set 8 | emirdag
# Processing Record 5 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 8 | slave lake
# Processing Record 7 of Set 8 | santa rosa
# Processing Record 8 of Set 8 | saint-augustin
# Processing Record 9 of Set 8 | chapais
# Processing Record 10 of Set 8 | le vauclin
# Processing Record 11 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 8 | clyde river
# Processing Record 13 of Set 8 | cabinda
# Processing Record 14 of Set 8 | katsuura
# Processing Record 15 of Set 8 | ahipara
# Processing Record 16 of Set 8 | saurimo
# Processing Record 17 of Set 8 | keti bandar
# Processing Record 18 of Set 8 | troitskoye
# Processing Record 19 of Set 8 | virtsu
# Processing Record 20 of Set 8 | soure
# Processing Record 21 of Set 8 | korla
# Processing Record 22 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 8 | boromo
# Processing Record 24 of Set 8 | raiwala
# Processing Record 25 of Set 8 | honningsvag
# Processing Record 26 of Set 8 | auki
# Processing Record 27 of Set 8 | tautira
# Processing Record 28 of Set 8 | aklavik
# Processing Record 29 of Set 8 | kloulklubed
# Processing Record 30 of Set 8 | beringovskiy
# Processing Record 31 of Set 8 | najran
# Processing Record 32 of Set 8 | yumen
# Processing Record 33 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 8 | martapura
# Processing Record 35 of Set 8 | dubbo
# Processing Record 36 of Set 8 | srandakan
# Processing Record 37 of Set 8 | saint-georges
# Processing Record 38 of Set 8 | otradnoye
# Processing Record 39 of Set 8 | gweta
# Processing Record 40 of Set 8 | millington
# Processing Record 41 of Set 8 | datong
# Processing Record 42 of Set 8 | ilulissat
# Processing Record 43 of Set 8 | lalibela
# Processing Record 44 of Set 8 | zuwarah
# Processing Record 45 of Set 8 | portland
# Processing Record 46 of Set 8 | takoradi
# Processing Record 47 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 8 | bereda
# Processing Record 49 of Set 8 | batemans bay
# Processing Record 50 of Set 8 | kidal
# Processing Record 1 of Set 9 | thinadhoo
# Processing Record 2 of Set 9 | snyder
# Processing Record 3 of Set 9 | half moon bay
# Processing Record 4 of Set 9 | moindou
# Processing Record 5 of Set 9 | quchan
# Processing Record 6 of Set 9 | comodoro rivadavia
# Processing Record 7 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 9 | windhoek
# Processing Record 9 of Set 9 | storslett
# Processing Record 10 of Set 9 | port macquarie
# Processing Record 11 of Set 9 | kuusamo
# Processing Record 12 of Set 9 | shitanjing
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 9 | sapele
# Processing Record 16 of Set 9 | srednekolymsk
# Processing Record 17 of Set 9 | mayumba
# Processing Record 18 of Set 9 | maracai
# Processing Record 19 of Set 9 | tabou
# Processing Record 20 of Set 9 | fecamp
# Processing Record 21 of Set 9 | ostrov
# Processing Record 22 of Set 9 | halifax
# Processing Record 23 of Set 9 | ust-tsilma
# Processing Record 24 of Set 9 | nouadhibou
# Processing Record 25 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 9 | baykit
# Processing Record 27 of Set 9 | bud
# Processing Record 28 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 9 | poum
# Processing Record 30 of Set 9 | bambous virieux
# Processing Record 31 of Set 9 | khakhea
# Processing Record 32 of Set 9 | hobyo
# Processing Record 33 of Set 9 | pokrovsk
# Processing Record 34 of Set 9 | boone
# Processing Record 35 of Set 9 | hailar
# Processing Record 36 of Set 9 | tura
# Processing Record 37 of Set 9 | may pen
# Processing Record 38 of Set 9 | vicuna
# Processing Record 39 of Set 9 | eureka
# Processing Record 40 of Set 9 | fos-sur-mer
# Processing Record 41 of Set 9 | monchegorsk
# Processing Record 42 of Set 9 | spearfish
# Processing Record 43 of Set 9 | salalah
# Processing Record 44 of Set 9 | san carlos de bariloche
# Processing Record 45 of Set 9 | cananea
# Processing Record 46 of Set 9 | coihaique
# Processing Record 47 of Set 9 | udpura
# Processing Record 48 of Set 9 | ponta delgada
# Processing Record 49 of Set 9 | ostrovnoy
# Processing Record 50 of Set 9 | tingi
# Processing Record 1 of Set 10 | oranjestad
# Processing Record 2 of Set 10 | karratha
# Processing Record 3 of Set 10 | ekibastuz
# Processing Record 4 of Set 10 | sambava
# Processing Record 5 of Set 10 | ondjiva
# Processing Record 6 of Set 10 | naga
# Processing Record 7 of Set 10 | noumea
# Processing Record 8 of Set 10 | raudeberg
# Processing Record 9 of Set 10 | kandrian
# Processing Record 10 of Set 10 | nueva loja
# Processing Record 11 of Set 10 | kralendijk
# Processing Record 12 of Set 10 | rancho palos verdes
# Processing Record 13 of Set 10 | nuevo progreso
# Processing Record 14 of Set 10 | kuryk
# Processing Record 15 of Set 10 | amapa
# Processing Record 16 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 10 | salisbury
# Processing Record 18 of Set 10 | tallahassee
# Processing Record 19 of Set 10 | puerto cabezas
# Processing Record 20 of Set 10 | luau
# Processing Record 21 of Set 10 | la asuncion
# Processing Record 22 of Set 10 | sandviken
# Processing Record 23 of Set 10 | vestmannaeyjar
# Processing Record 24 of Set 10 | kangaatsiaq
# Processing Record 25 of Set 10 | silver city
# Processing Record 26 of Set 10 | sao filipe
# Processing Record 27 of Set 10 | rafaela
# Processing Record 28 of Set 10 | impfondo
# Processing Record 29 of Set 10 | southbridge
# Processing Record 30 of Set 10 | namatanai
# Processing Record 31 of Set 10 | chicaman
# Processing Record 32 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 10 | qandala
# Processing Record 34 of Set 10 | tuatapere
# Processing Record 35 of Set 10 | dawson creek
# Processing Record 36 of Set 10 | japura
# Processing Record 37 of Set 10 | vostok
# Processing Record 38 of Set 10 | olinda
# Processing Record 39 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 10 | tumbagaan
# Processing Record 41 of Set 10 | puerto escondido
# Processing Record 42 of Set 10 | zhezkazgan
# Processing Record 43 of Set 10 | constitucion
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | tahta
# Processing Record 46 of Set 10 | gornopravdinsk
# Processing Record 47 of Set 10 | akdepe
# Processing Record 48 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 49 of Set 10 | havre-saint-pierre
# Processing Record 50 of Set 10 | port hawkesbury
# Processing Record 1 of Set 11 | nacala
# Processing Record 2 of Set 11 | conakry
# Processing Record 3 of Set 11 | ayan
# Processing Record 4 of Set 11 | tarakan
# Processing Record 5 of Set 11 | xuddur
# Processing Record 6 of Set 11 | steamboat springs
# Processing Record 7 of Set 11 | cairns
# Processing Record 8 of Set 11 | puerto carreno
# Processing Record 9 of Set 11 | awbari
# Processing Record 10 of Set 11 | yar-sale
# Processing Record 11 of Set 11 | port hope
# Processing Record 12 of Set 11 | west bay
# Processing Record 13 of Set 11 | kapit
# Processing Record 14 of Set 11 | sistranda
# Processing Record 15 of Set 11 | garango
# Processing Record 16 of Set 11 | rantauprapat
# Processing Record 17 of Set 11 | trairi
# Processing Record 18 of Set 11 | eisiskes
# Processing Record 19 of Set 11 | lichtenvoorde
# Processing Record 20 of Set 11 | borogontsy
# Processing Record 21 of Set 11 | udayagiri
# Processing Record 22 of Set 11 | avigliano
# Processing Record 23 of Set 11 | nador
# Processing Record 24 of Set 11 | kaeo
# Processing Record 25 of Set 11 | platteville
# Processing Record 26 of Set 11 | lorengau
# Processing Record 27 of Set 11 | port blair
# Processing Record 28 of Set 11 | severo-yeniseyskiy
# Processing Record 29 of Set 11 | nova olimpia
# Processing Record 30 of Set 11 | saskylakh
# Processing Record 31 of Set 11 | sungai besar
# Processing Record 32 of Set 11 | makakilo city
# Processing Record 33 of Set 11 | komsomolets
# Processing Record 34 of Set 11 | duldurga
# Processing Record 35 of Set 11 | port-gentil
# Processing Record 36 of Set 11 | progreso
# Processing Record 37 of Set 11 | kawalu
# Processing Record 38 of Set 11 | erenhot
# Processing Record 39 of Set 11 | bayevo
# Processing Record 40 of Set 11 | mikhaylovka
# Processing Record 41 of Set 11 | ketchikan
# Processing Record 42 of Set 11 | meilu
# City not found. Skipping...
# Processing Record 43 of Set 11 | gemena
# Processing Record 44 of Set 11 | tilichiki
# Processing Record 45 of Set 11 | khasan
# Processing Record 46 of Set 11 | tsybuliv
# Processing Record 47 of Set 11 | periban
# City not found. Skipping...
# Processing Record 48 of Set 11 | snezhnogorsk
# Processing Record 49 of Set 11 | plettenberg bay
# Processing Record 50 of Set 11 | santana do matos
# Processing Record 1 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 2 of Set 12 | eugene
# Processing Record 3 of Set 12 | ouesso
# Processing Record 4 of Set 12 | broome
# Processing Record 5 of Set 12 | riohacha
# Processing Record 6 of Set 12 | velizh
# Processing Record 7 of Set 12 | kahului
# Processing Record 8 of Set 12 | nsanje
# Processing Record 9 of Set 12 | bobrov
# Processing Record 10 of Set 12 | kenitra
# Processing Record 11 of Set 12 | florence
# Processing Record 12 of Set 12 | xichang
# Processing Record 13 of Set 12 | cobija
# Processing Record 14 of Set 12 | kishtwar
# Processing Record 15 of Set 12 | geraldton
# Processing Record 16 of Set 12 | nishihara
# Processing Record 17 of Set 12 | gorele
# Processing Record 18 of Set 12 | wajid
# Processing Record 19 of Set 12 | mmabatho
# Processing Record 20 of Set 12 | muzhi
# Processing Record 21 of Set 12 | haines junction
# Processing Record 22 of Set 12 | la plata
# Processing Record 23 of Set 12 | jizan
# Processing Record 24 of Set 12 | harare
# Processing Record 25 of Set 12 | cap malheureux
# Processing Record 26 of Set 12 | laguna
# Processing Record 27 of Set 12 | metro
# Processing Record 28 of Set 12 | porto novo
# Processing Record 29 of Set 12 | kushmurun
# Processing Record 30 of Set 12 | huarmey
# Processing Record 31 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 12 | susanville
# Processing Record 33 of Set 12 | rondonopolis
# Processing Record 34 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 12 | allapalli
# Processing Record 36 of Set 12 | kupang
# Processing Record 37 of Set 12 | las vegas
# Processing Record 38 of Set 12 | lasa
# Processing Record 39 of Set 12 | ust-ishim
# Processing Record 40 of Set 12 | parabel
# Processing Record 41 of Set 12 | bodden town
# Processing Record 42 of Set 12 | mnogovershinnyy
# Processing Record 43 of Set 12 | general roca
# Processing Record 44 of Set 12 | sao gabriel da cachoeira
# Processing Record 45 of Set 12 | kokino
# Processing Record 46 of Set 12 | nimaparha
# Processing Record 47 of Set 12 | hope
# Processing Record 48 of Set 12 | karasjok
# Processing Record 49 of Set 12 | zapolyarnyy
# Processing Record 50 of Set 12 | stornoway
# Processing Record 1 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 13 | linaon
# Processing Record 4 of Set 13 | portadown
# Processing Record 5 of Set 13 | uhlove
# Processing Record 6 of Set 13 | svetlogorsk
# Processing Record 7 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 13 | maldonado
# Processing Record 9 of Set 13 | aquiraz
# Processing Record 10 of Set 13 | pushkino
# Processing Record 11 of Set 13 | ubrique
# Processing Record 12 of Set 13 | san jose de los arroyos
# City not found. Skipping...
# Processing Record 13 of Set 13 | lanzhou
# Processing Record 14 of Set 13 | marsala
# Processing Record 15 of Set 13 | zhovti vody
# Processing Record 16 of Set 13 | teya
# Processing Record 17 of Set 13 | lata
# Processing Record 18 of Set 13 | rio de janeiro
# Processing Record 19 of Set 13 | saldanha
# Processing Record 20 of Set 13 | vagur
# Processing Record 21 of Set 13 | sterling
# Processing Record 22 of Set 13 | san lawrenz
# Processing Record 23 of Set 13 | adana
# Processing Record 24 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 13 | kyzyl-suu
# Processing Record 26 of Set 13 | paita
# Processing Record 27 of Set 13 | trabzon
# Processing Record 28 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 29 of Set 13 | mana
# Processing Record 30 of Set 13 | galveston
# Processing Record 31 of Set 13 | yermolino
# Processing Record 32 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 13 | yerbogachen
# Processing Record 34 of Set 13 | odweyne
# Processing Record 35 of Set 13 | salta
# Processing Record 36 of Set 13 | polunochnoye
# Processing Record 37 of Set 13 | alta floresta
# Processing Record 38 of Set 13 | pokrovskoye
# Processing Record 39 of Set 13 | nizwa
# Processing Record 40 of Set 13 | am timan
# Processing Record 41 of Set 13 | la ronge
# Processing Record 42 of Set 13 | moron
# Processing Record 43 of Set 13 | san andres
# Processing Record 44 of Set 13 | salekhard
# Processing Record 45 of Set 13 | cedar city
# Processing Record 46 of Set 13 | homer
# Processing Record 47 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 13 | praya
# Processing Record 50 of Set 13 | los chiles
# Processing Record 1 of Set 14 | dubrovka
# Processing Record 2 of Set 14 | mareeba
# Processing Record 3 of Set 14 | san patricio
# Processing Record 4 of Set 14 | muisne
# Processing Record 5 of Set 14 | wanning
# Processing Record 6 of Set 14 | padang
# Processing Record 7 of Set 14 | kinablangan
# Processing Record 8 of Set 14 | atikokan
# Processing Record 9 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 14 | na wa
# Processing Record 11 of Set 14 | aasiaat
# Processing Record 12 of Set 14 | tazovskiy
# Processing Record 13 of Set 14 | yatou
# Processing Record 14 of Set 14 | lat yao
# Processing Record 15 of Set 14 | longyearbyen
# Processing Record 16 of Set 14 | svetlaya
# Processing Record 17 of Set 14 | boundiali
# Processing Record 18 of Set 14 | berdigestyakh
# Processing Record 19 of Set 14 | nha trang
# Processing Record 20 of Set 14 | mandurah
# Processing Record 21 of Set 14 | sfantu gheorghe
# Processing Record 22 of Set 14 | martinsburg
# Processing Record 23 of Set 14 | natal
# Processing Record 24 of Set 14 | okha
# Processing Record 25 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 14 | kiama
# Processing Record 27 of Set 14 | aswan
# Processing Record 28 of Set 14 | pingxiang
# Processing Record 29 of Set 14 | sibolga
# Processing Record 30 of Set 14 | pangkalanbuun
# Processing Record 31 of Set 14 | chicama
# Processing Record 32 of Set 14 | puerto asis
# Processing Record 33 of Set 14 | mahon
# Processing Record 34 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 14 | yablochnyy
# Processing Record 36 of Set 14 | deputatskiy
# Processing Record 37 of Set 14 | beohari
# Processing Record 38 of Set 14 | rantepao
# Processing Record 39 of Set 14 | springbok
# Processing Record 40 of Set 14 | jinchang
# Processing Record 41 of Set 14 | miles city
# Processing Record 42 of Set 14 | santa cruz cabralia
# Processing Record 43 of Set 14 | iskateley
# Processing Record 44 of Set 14 | sobolevo
# Processing Record 45 of Set 14 | enumclaw
# Processing Record 46 of Set 14 | scarborough
# Processing Record 47 of Set 14 | poya
# Processing Record 48 of Set 14 | wukari
# Processing Record 49 of Set 14 | calvini
# Processing Record 50 of Set 14 | kieta
# Processing Record 1 of Set 15 | porbandar
# Processing Record 2 of Set 15 | rafai
# Processing Record 3 of Set 15 | samaipata
# Processing Record 4 of Set 15 | mokobeng
# Processing Record 5 of Set 15 | muzaffarabad
# Processing Record 6 of Set 15 | tsiroanomandidy
# Processing Record 7 of Set 15 | chiredzi
# Processing Record 8 of Set 15 | eyl
# Processing Record 9 of Set 15 | kudat
# Processing Record 10 of Set 15 | calabozo
# Processing Record 11 of Set 15 | bizhbulyak
# Processing Record 12 of Set 15 | payakumbuh
# Processing Record 13 of Set 15 | maxixe
# Processing Record 14 of Set 15 | menongue
# Processing Record 15 of Set 15 | tungor
# Processing Record 16 of Set 15 | jalu
# Processing Record 17 of Set 15 | buala
# Processing Record 18 of Set 15 | holland
# Processing Record 19 of Set 15 | columbus
# Processing Record 20 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 15 | sisimiut
# Processing Record 22 of Set 15 | shirokiy
# Processing Record 23 of Set 15 | akim swedru
# Processing Record 24 of Set 15 | port pirie
# Processing Record 25 of Set 15 | azogues
# Processing Record 26 of Set 15 | churachandpur
# Processing Record 27 of Set 15 | tucumcari
# Processing Record 28 of Set 15 | whitianga
# Processing Record 29 of Set 15 | cabedelo
# Processing Record 30 of Set 15 | playa del carmen
# Processing Record 31 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 15 | busdi
# Processing Record 33 of Set 15 | abalak
# Processing Record 34 of Set 15 | rawson
# Processing Record 35 of Set 15 | agua verde
# Processing Record 36 of Set 15 | suez
# Processing Record 37 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 15 | brae
# Processing Record 39 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 15 | jieshi
# Processing Record 41 of Set 15 | siguiri
# Processing Record 42 of Set 15 | richards bay
# Processing Record 43 of Set 15 | jumla
# Processing Record 44 of Set 15 | yigou
# Processing Record 45 of Set 15 | uzunkopru
# City not found. Skipping...
# Processing Record 46 of Set 15 | bulgan
# Processing Record 47 of Set 15 | zaraza
# Processing Record 48 of Set 15 | moyale
# Processing Record 49 of Set 15 | warkworth
# Processing Record 50 of Set 15 | taoudenni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Reorder Columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Resave df with new columns
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Hithadhoo      MV  -0.6000   73.0833     81.36        76
# 1  San Jose De Rio Tinto      HN  14.9333  -85.7000     71.10        83
# 2                   Chuy      UY -33.6971  -53.4616     66.58        90
# 3               Ambilobe      MG -13.2000   49.0500     72.72        94
# 4                 Dezhou      CN  37.4486  116.2925     37.53        73
# 5                Rikitea      PF -23.1203 -134.9692     78.78        69
# 6                  Vaini      TO -21.2000 -175.2000     84.20        84
# 7                 Ingham      US  42.6000  -84.3833     16.00        86
# 8               Cidreira      BR -30.1811  -50.2056     67.93        75
# 9             Warrington      GB  53.3925   -2.5802     39.20        81
#
#    Cloudiness  Wind Speed Current Description
# 0           0       12.19           clear sky
# 1           0        3.42           clear sky
# 2           0        8.77           clear sky
# 3          99        2.75     overcast clouds
# 4           0       13.96           clear sky
# 5          73       10.56       broken clouds
# 6          75        9.22       broken clouds
# 7          90        4.61          light snow
# 8          71        6.02       broken clouds
# 9          75       19.57       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
